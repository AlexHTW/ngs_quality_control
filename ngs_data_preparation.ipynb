# %% [markdown]
# # Machine Learning Evaluation of NGS Fastqc Results

# %% [markdown]
# ## Import fastqc results into a dataframe

# %% [markdown]
# # Import fastqQCParser
# https://pypi.org/project/fastqcparser/#description

# %%
from pprint import pprint
from fastqcparser import FastQCParser

# %%
import pandas as pd
import os

# %%
rootdir = 'training_data' #os.path.abspath(os.curdir)

# %%
def import_reads(rootdir):
    reads = []
    for root, dirs, files in os.walk(rootdir):
        for name in files:
            filepath = root + os.sep + name
            if filepath.endswith("fastqc_data.txt"):
                reads.append(FastQCParser(filepath))
    return reads

# %%
reads = import_reads(rootdir)

# %%
len(reads)
# Out:
# 184

# %%
module_list = list(reads[0].modules.keys())
# imported reads don't include the module 'Overrepresented sequences' 
# if there are none in the read, so we manually add the module to the list
if(len(module_list) < 11):
    module_list.insert(9, 'Overrepresented sequences')
module_list.append('Module Statuses')
module_list.append('filename')
print(module_list)
# Out:
# ['Basic Statistics', 'Per base sequence quality', 'Per tile sequence quality', 'Per sequence quality scores', 'Per base sequence content', 'Per sequence GC content', 'Per base N content', 'Sequence Length Distribution', 'Sequence Duplication Levels', 'Overrepresented sequences', 'Adapter Content', 'Module Statuses', 'filename']

# %%
def create_single_read_dataframe(result):
    module_result = []
    module_status = []
    
    for module in result.modules:
        result_data = pd.DataFrame(result.modules[module]['data'])
        result_data.columns = result.modules[module]['fieldnames']
        module_status.append(result.modules[module]['status'])
        module_result.append(result_data)
    # imported reads don't include the module 'Overrepresented sequences' 
    # if there are none in the read, so we manually add the status list
    # and an empty dataframe /is None better?
    if len(module_status) < 11:
        module_status.insert(9, 'pass')
        module_result.insert(9, pd.DataFrame())
    module_result.append(module_status)
    module_result.append(module_result[0].Value[0].replace(".fastq.gz", ""))
    #print(len(module_result), ' - ',  module_result[0].Value[0], '-', len(module_list) )
    module_series = pd.Series(data=module_result, index=module_list)
    single_read = module_series.to_frame().T#.set_index('filename')
    return single_read

# %%
read_list = []
for read in reads:
    single_read = create_single_read_dataframe(read)
    read_list.append(single_read)

# %%
read_results = pd.concat(read_list)
read_results
# Out:
#                                      Basic Statistics  \
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# ..                                                ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
# 0                                Measure  \
# 0     ...
#
#                             Per base sequence quality  \
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# ..                                                ...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
# 0          Base       Mean  Median  Lower Quartile...
#
#                             Per tile sequence quality  \
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base       Mean
# 0     1102     ...
# ..                                                ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
# 0         Tile     Base      Mean
# 0     1101      ...
#
#                           Per sequence quality scores  \
# 0       Quality     Count
# 0         2       3.0
# 1 ...
# 0       Quality    Count
# 0        13      2.0
# 1   ...
# 0       Quality      Count
# 0         2     1668.0
# ...
# 0       Quality      Count
# 0        12        2.0
# ...
# 0       Quality  Count
# 0        15    3.0
# 1       ...
# ..                                                ...
# 0       Quality     Count
# 0        15       1.0
# 1 ...
# 0       Quality     Count
# 0         2       1.0
# 1 ...
# 0       Quality     Count
# 0        16       2.0
# 1 ...
# 0       Quality     Count
# 0         2       1.0
# 1 ...
# 0       Quality     Count
# 0        16       2.0
# 1 ...
#
#                             Per base sequence content  \
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# ..                                                ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
# 0          Base          G          A          T  ...
#
#                               Per sequence GC content  \
# 0        GC Content  Count
# 0             0   3.00
# ...
# 0        GC Content  Count
# 0             0    0.0
# ...
# 0        GC Content   Count
# 0             0  1668....
# 0        GC Content  Count
# 0             0    0.0
# ...
# 0        GC Content  Count
# 0             0    0.0
# ...
# ..                                                ...
# 0        GC Content  Count
# 0             0    0.0
# ...
# 0        GC Content      Count
# 0             0   3...
# 0        GC Content  Count
# 0             0    0.0
# ...
# 0        GC Content      Count
# 0             0   0...
# 0        GC Content  Count
# 0             0    0.0
# ...
#
#                                    Per base N content  \
# 0          Base   N-Count
# 0         1  0.479607
# 1 ...
# 0          Base   N-Count
# 0         1  0.009071
# 1 ...
# 0          Base   N-Count
# 0         1  0.029292
# 1 ...
# 0          Base  N-Count
# 0         1      0.0
# 1   ...
# 0          Base  N-Count
# 0         1      0.0
# 1   ...
# ..                                                ...
# 0          Base   N-Count
# 0         1  0.080016
# 1 ...
# 0          Base   N-Count
# 0         1  0.000708
# 1 ...
# 0          Base   N-Count
# 0         1  0.080888
# 1 ...
# 0          Base   N-Count
# 0         1  0.000365
# 1 ...
# 0          Base   N-Count
# 0         1  0.083286
# 1 ...
#
#                          Sequence Length Distribution  \
# 0        Length    Count
# 0     30-39   4192.0
# 1   ...
# 0        Length    Count
# 0     30-39    189.0
# 1   ...
# 0        Length      Count
# 0     30-39     4566.0
# ...
# 0        Length     Count
# 0     30-39    8954.0
# 1 ...
# 0        Length  Count
# 0     65-69    1.0
# 1     70...
# ..                                                ...
# 0        Length     Count
# 0     35-39    4455.0
# 1 ...
# 0        Length     Count
# 0     35-39    5799.0
# 1 ...
# 0        Length     Count
# 0     35-39    1949.0
# 1 ...
# 0        Length     Count
# 0     35-39    4278.0
# 1 ...
# 0        Length     Count
# 0     35-39    4284.0
# 1 ...
#
#                           Sequence Duplication Levels  \
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# ..                                                ...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
# 0      Duplication Level  Percentage of deduplicat...
#
#                             Overrepresented sequences  \
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0                                                 ...
# ..                                                ...
# 0                                               Se...
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0                                               Se...
# 0               Empty DataFrame
# Columns: []
# Index: []
# 0               Empty DataFrame
# Columns: []
# Index: []
#
#                                       Adapter Content  \
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# ..                                                ...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
# 0      Position  Illumina Universal Adapter  Illum...
#
#                                       Module Statuses  \
# 0   [pass, fail, pass, pass, fail, pass, pass, war...
# 0   [pass, pass, warn, pass, fail, pass, pass, war...
# 0   [pass, fail, warn, pass, fail, warn, pass, war...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
# 0   [pass, fail, fail, pass, fail, fail, pass, war...
# ..                                                ...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
# 0   [pass, pass, pass, pass, fail, pass, pass, war...
#
#                                     filename
# 0   200709_20-07968_20-00891_S21_L000_R2_001
# 0    200204_20-00746_19-03927_S9_L000_R1_001
# 0       181002-18-6991-775-18_S1_L001_R1_001
# 0   200327_20-04028_20-00328_S25_L000_R1_001
# 0     180727-18-5425-18-01680_S8_L001_R2_001
# ..                                       ...
# 0     191113_19-10152_20476_S134_L000_R1_001
# 0     191113_19-10150_20474_S132_L000_R2_001
# 0     191113_19-10153_20477_S135_L000_R1_001
# 0     191113_19-10151_20475_S133_L000_R2_001
# 0     191113_19-10151_20475_S133_L000_R1_001
#
# [184 rows x 13 columns]

# %%
pd.set_option('display.max_rows', 10)

# %%
metadata = pd.read_json('exported_datasets/metadata.json')
metadata
# Out:
#                                      filename organism technology  \
# 0    200709_20-07968_20-00891_S21_L000_R2_001      Sau         MS
# 1     200204_20-00746_19-03927_S9_L000_R1_001      Sau         MS
# 2        181002-18-6991-775-18_S1_L001_R1_001      Sau         MS
# 3    200327_20-04028_20-00328_S25_L000_R1_001      Sau         MS
# 4      180727-18-5425-18-01680_S8_L001_R2_001      Sau         MS
# ..                                        ...      ...        ...
# 179    191113_19-10152_20476_S134_L000_R1_001     Efcm         HS
# 180    191113_19-10150_20474_S132_L000_R2_001     Efcm         HS
# 181    191113_19-10153_20477_S135_L000_R1_001     Efcm         HS
# 182    191113_19-10151_20475_S133_L000_R2_001     Efcm         HS
# 183    191113_19-10151_20475_S133_L000_R1_001     Efcm         HS
#
#      read_number evaluation
# 0              2       ugly
# 1              1       ugly
# 2              1       ugly
# 3              1       ugly
# 4              2       ugly
# ..           ...        ...
# 179            1       good
# 180            2       good
# 181            1       good
# 182            2       good
# 183            1       good
#
# [184 rows x 5 columns]

# %%
complete_reads = pd.merge(read_results, metadata, on='filename', how='inner').set_index('filename')
complete_reads
# Out:
#                                                                            Basic Statistics  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001                               Measure  \
# 0     ...
# 200204_20-00746_19-03927_S9_L000_R1_001                                Measure  \
# 0     ...
# 181002-18-6991-775-18_S1_L001_R1_001                                   Measure  \
# 0     ...
# 200327_20-04028_20-00328_S25_L000_R1_001                               Measure  \
# 0     ...
# 180727-18-5425-18-01680_S8_L001_R2_001                                 Measure  \
# 0     ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001                                 Measure  \
# 0     ...
# 191113_19-10150_20474_S132_L000_R2_001                                 Measure  \
# 0     ...
# 191113_19-10153_20477_S135_L000_R1_001                                 Measure  \
# 0     ...
# 191113_19-10151_20475_S133_L000_R2_001                                 Measure  \
# 0     ...
# 191113_19-10151_20475_S133_L000_R1_001                                 Measure  \
# 0     ...
#
#                                                                   Per base sequence quality  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base       Mean  Median  Lower Quartile...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base       Mean  Median  Lower Quartile...
# 181002-18-6991-775-18_S1_L001_R1_001             Base       Mean  Median  Lower Quartile...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base       Mean  Median  Lower Quartile...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base       Mean  Median  Lower Quartile...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10150_20474_S132_L000_R2_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10153_20477_S135_L000_R1_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10151_20475_S133_L000_R2_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10151_20475_S133_L000_R1_001           Base       Mean  Median  Lower Quartile...
#
#                                                                   Per tile sequence quality  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001        Tile     Base      Mean
# 0     1101      ...
# 200204_20-00746_19-03927_S9_L000_R1_001         Tile     Base      Mean
# 0     1101      ...
# 181002-18-6991-775-18_S1_L001_R1_001            Tile     Base      Mean
# 0     1101      ...
# 200327_20-04028_20-00328_S25_L000_R1_001        Tile     Base      Mean
# 0     1101      ...
# 180727-18-5425-18-01680_S8_L001_R2_001          Tile     Base       Mean
# 0     1102     ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10150_20474_S132_L000_R2_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10153_20477_S135_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10151_20475_S133_L000_R2_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10151_20475_S133_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
#
#                                                                 Per sequence quality scores  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001      Quality     Count
# 0         2       3.0
# 1 ...
# 200204_20-00746_19-03927_S9_L000_R1_001       Quality    Count
# 0        13      2.0
# 1   ...
# 181002-18-6991-775-18_S1_L001_R1_001          Quality      Count
# 0         2     1668.0
# ...
# 200327_20-04028_20-00328_S25_L000_R1_001      Quality      Count
# 0        12        2.0
# ...
# 180727-18-5425-18-01680_S8_L001_R2_001        Quality  Count
# 0        15    3.0
# 1       ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001        Quality     Count
# 0        15       1.0
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001        Quality     Count
# 0         2       1.0
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001        Quality     Count
# 0        16       2.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001        Quality     Count
# 0         2       1.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001        Quality     Count
# 0        16       2.0
# 1 ...
#
#                                                                   Per base sequence content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base          G          A          T  ...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base          G          A          T  ...
# 181002-18-6991-775-18_S1_L001_R1_001             Base          G          A          T  ...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base          G          A          T  ...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base          G          A          T  ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base          G          A          T  ...
# 191113_19-10150_20474_S132_L000_R2_001           Base          G          A          T  ...
# 191113_19-10153_20477_S135_L000_R1_001           Base          G          A          T  ...
# 191113_19-10151_20475_S133_L000_R2_001           Base          G          A          T  ...
# 191113_19-10151_20475_S133_L000_R1_001           Base          G          A          T  ...
#
#                                                                     Per sequence GC content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001       GC Content  Count
# 0             0   3.00
# ...
# 200204_20-00746_19-03927_S9_L000_R1_001        GC Content  Count
# 0             0    0.0
# ...
# 181002-18-6991-775-18_S1_L001_R1_001           GC Content   Count
# 0             0  1668....
# 200327_20-04028_20-00328_S25_L000_R1_001       GC Content  Count
# 0             0    0.0
# ...
# 180727-18-5425-18-01680_S8_L001_R2_001         GC Content  Count
# 0             0    0.0
# ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
# 191113_19-10150_20474_S132_L000_R2_001         GC Content      Count
# 0             0   3...
# 191113_19-10153_20477_S135_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
# 191113_19-10151_20475_S133_L000_R2_001         GC Content      Count
# 0             0   0...
# 191113_19-10151_20475_S133_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
#
#                                                                          Per base N content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base   N-Count
# 0         1  0.479607
# 1 ...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base   N-Count
# 0         1  0.009071
# 1 ...
# 181002-18-6991-775-18_S1_L001_R1_001             Base   N-Count
# 0         1  0.029292
# 1 ...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base  N-Count
# 0         1      0.0
# 1   ...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base  N-Count
# 0         1      0.0
# 1   ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base   N-Count
# 0         1  0.080016
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001           Base   N-Count
# 0         1  0.000708
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001           Base   N-Count
# 0         1  0.080888
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001           Base   N-Count
# 0         1  0.000365
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001           Base   N-Count
# 0         1  0.083286
# 1 ...
#
#                                                                Sequence Length Distribution  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001       Length    Count
# 0     30-39   4192.0
# 1   ...
# 200204_20-00746_19-03927_S9_L000_R1_001        Length    Count
# 0     30-39    189.0
# 1   ...
# 181002-18-6991-775-18_S1_L001_R1_001           Length      Count
# 0     30-39     4566.0
# ...
# 200327_20-04028_20-00328_S25_L000_R1_001       Length     Count
# 0     30-39    8954.0
# 1 ...
# 180727-18-5425-18-01680_S8_L001_R2_001         Length  Count
# 0     65-69    1.0
# 1     70...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001         Length     Count
# 0     35-39    4455.0
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001         Length     Count
# 0     35-39    5799.0
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001         Length     Count
# 0     35-39    1949.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001         Length     Count
# 0     35-39    4278.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001         Length     Count
# 0     35-39    4284.0
# 1 ...
#
#                                                                 Sequence Duplication Levels  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001     Duplication Level  Percentage of deduplicat...
# 200204_20-00746_19-03927_S9_L000_R1_001      Duplication Level  Percentage of deduplicat...
# 181002-18-6991-775-18_S1_L001_R1_001         Duplication Level  Percentage of deduplicat...
# 200327_20-04028_20-00328_S25_L000_R1_001     Duplication Level  Percentage of deduplicat...
# 180727-18-5425-18-01680_S8_L001_R2_001       Duplication Level  Percentage of deduplicat...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10150_20474_S132_L000_R2_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10153_20477_S135_L000_R1_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10151_20475_S133_L000_R2_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10151_20475_S133_L000_R1_001       Duplication Level  Percentage of deduplicat...
#
#                                                                   Overrepresented sequences  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001              Empty DataFrame
# Columns: []
# Index: []
# 200204_20-00746_19-03927_S9_L000_R1_001               Empty DataFrame
# Columns: []
# Index: []
# 181002-18-6991-775-18_S1_L001_R1_001                  Empty DataFrame
# Columns: []
# Index: []
# 200327_20-04028_20-00328_S25_L000_R1_001              Empty DataFrame
# Columns: []
# Index: []
# 180727-18-5425-18-01680_S8_L001_R2_001                                                  ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001                                                Se...
# 191113_19-10150_20474_S132_L000_R2_001                Empty DataFrame
# Columns: []
# Index: []
# 191113_19-10153_20477_S135_L000_R1_001                                                Se...
# 191113_19-10151_20475_S133_L000_R2_001                Empty DataFrame
# Columns: []
# Index: []
# 191113_19-10151_20475_S133_L000_R1_001                Empty DataFrame
# Columns: []
# Index: []
#
#                                                                             Adapter Content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001     Position  Illumina Universal Adapter  Illum...
# 200204_20-00746_19-03927_S9_L000_R1_001      Position  Illumina Universal Adapter  Illum...
# 181002-18-6991-775-18_S1_L001_R1_001         Position  Illumina Universal Adapter  Illum...
# 200327_20-04028_20-00328_S25_L000_R1_001     Position  Illumina Universal Adapter  Illum...
# 180727-18-5425-18-01680_S8_L001_R2_001       Position  Illumina Universal Adapter  Illum...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10150_20474_S132_L000_R2_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10153_20477_S135_L000_R1_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10151_20475_S133_L000_R2_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10151_20475_S133_L000_R1_001       Position  Illumina Universal Adapter  Illum...
#
#                                                                             Module Statuses  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001  [pass, fail, pass, pass, fail, pass, pass, war...
# 200204_20-00746_19-03927_S9_L000_R1_001   [pass, pass, warn, pass, fail, pass, pass, war...
# 181002-18-6991-775-18_S1_L001_R1_001      [pass, fail, warn, pass, fail, warn, pass, war...
# 200327_20-04028_20-00328_S25_L000_R1_001  [pass, pass, pass, pass, fail, pass, pass, war...
# 180727-18-5425-18-01680_S8_L001_R2_001    [pass, fail, fail, pass, fail, fail, pass, war...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10150_20474_S132_L000_R2_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10153_20477_S135_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10151_20475_S133_L000_R2_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10151_20475_S133_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
#
#                                          organism technology  read_number  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001      Sau         MS            2
# 200204_20-00746_19-03927_S9_L000_R1_001       Sau         MS            1
# 181002-18-6991-775-18_S1_L001_R1_001          Sau         MS            1
# 200327_20-04028_20-00328_S25_L000_R1_001      Sau         MS            1
# 180727-18-5425-18-01680_S8_L001_R2_001        Sau         MS            2
# ...                                           ...        ...          ...
# 191113_19-10152_20476_S134_L000_R1_001       Efcm         HS            1
# 191113_19-10150_20474_S132_L000_R2_001       Efcm         HS            2
# 191113_19-10153_20477_S135_L000_R1_001       Efcm         HS            1
# 191113_19-10151_20475_S133_L000_R2_001       Efcm         HS            2
# 191113_19-10151_20475_S133_L000_R1_001       Efcm         HS            1
#
#                                          evaluation
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001       ugly
# 200204_20-00746_19-03927_S9_L000_R1_001        ugly
# 181002-18-6991-775-18_S1_L001_R1_001           ugly
# 200327_20-04028_20-00328_S25_L000_R1_001       ugly
# 180727-18-5425-18-01680_S8_L001_R2_001         ugly
# ...                                             ...
# 191113_19-10152_20476_S134_L000_R1_001         good
# 191113_19-10150_20474_S132_L000_R2_001         good
# 191113_19-10153_20477_S135_L000_R1_001         good
# 191113_19-10151_20475_S133_L000_R2_001         good
# 191113_19-10151_20475_S133_L000_R1_001         good
#
# [184 rows x 16 columns]

# %%
complete_reads['evaluation'].replace({'ugly': 0, 'good': 1}, inplace=True)
complete_reads
# Out:
#                                                                            Basic Statistics  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001                               Measure  \
# 0     ...
# 200204_20-00746_19-03927_S9_L000_R1_001                                Measure  \
# 0     ...
# 181002-18-6991-775-18_S1_L001_R1_001                                   Measure  \
# 0     ...
# 200327_20-04028_20-00328_S25_L000_R1_001                               Measure  \
# 0     ...
# 180727-18-5425-18-01680_S8_L001_R2_001                                 Measure  \
# 0     ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001                                 Measure  \
# 0     ...
# 191113_19-10150_20474_S132_L000_R2_001                                 Measure  \
# 0     ...
# 191113_19-10153_20477_S135_L000_R1_001                                 Measure  \
# 0     ...
# 191113_19-10151_20475_S133_L000_R2_001                                 Measure  \
# 0     ...
# 191113_19-10151_20475_S133_L000_R1_001                                 Measure  \
# 0     ...
#
#                                                                   Per base sequence quality  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base       Mean  Median  Lower Quartile...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base       Mean  Median  Lower Quartile...
# 181002-18-6991-775-18_S1_L001_R1_001             Base       Mean  Median  Lower Quartile...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base       Mean  Median  Lower Quartile...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base       Mean  Median  Lower Quartile...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10150_20474_S132_L000_R2_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10153_20477_S135_L000_R1_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10151_20475_S133_L000_R2_001           Base       Mean  Median  Lower Quartile...
# 191113_19-10151_20475_S133_L000_R1_001           Base       Mean  Median  Lower Quartile...
#
#                                                                   Per tile sequence quality  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001        Tile     Base      Mean
# 0     1101      ...
# 200204_20-00746_19-03927_S9_L000_R1_001         Tile     Base      Mean
# 0     1101      ...
# 181002-18-6991-775-18_S1_L001_R1_001            Tile     Base      Mean
# 0     1101      ...
# 200327_20-04028_20-00328_S25_L000_R1_001        Tile     Base      Mean
# 0     1101      ...
# 180727-18-5425-18-01680_S8_L001_R2_001          Tile     Base       Mean
# 0     1102     ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10150_20474_S132_L000_R2_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10153_20477_S135_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10151_20475_S133_L000_R2_001          Tile     Base      Mean
# 0     1101      ...
# 191113_19-10151_20475_S133_L000_R1_001          Tile     Base      Mean
# 0     1101      ...
#
#                                                                 Per sequence quality scores  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001      Quality     Count
# 0         2       3.0
# 1 ...
# 200204_20-00746_19-03927_S9_L000_R1_001       Quality    Count
# 0        13      2.0
# 1   ...
# 181002-18-6991-775-18_S1_L001_R1_001          Quality      Count
# 0         2     1668.0
# ...
# 200327_20-04028_20-00328_S25_L000_R1_001      Quality      Count
# 0        12        2.0
# ...
# 180727-18-5425-18-01680_S8_L001_R2_001        Quality  Count
# 0        15    3.0
# 1       ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001        Quality     Count
# 0        15       1.0
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001        Quality     Count
# 0         2       1.0
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001        Quality     Count
# 0        16       2.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001        Quality     Count
# 0         2       1.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001        Quality     Count
# 0        16       2.0
# 1 ...
#
#                                                                   Per base sequence content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base          G          A          T  ...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base          G          A          T  ...
# 181002-18-6991-775-18_S1_L001_R1_001             Base          G          A          T  ...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base          G          A          T  ...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base          G          A          T  ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base          G          A          T  ...
# 191113_19-10150_20474_S132_L000_R2_001           Base          G          A          T  ...
# 191113_19-10153_20477_S135_L000_R1_001           Base          G          A          T  ...
# 191113_19-10151_20475_S133_L000_R2_001           Base          G          A          T  ...
# 191113_19-10151_20475_S133_L000_R1_001           Base          G          A          T  ...
#
#                                                                     Per sequence GC content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001       GC Content  Count
# 0             0   3.00
# ...
# 200204_20-00746_19-03927_S9_L000_R1_001        GC Content  Count
# 0             0    0.0
# ...
# 181002-18-6991-775-18_S1_L001_R1_001           GC Content   Count
# 0             0  1668....
# 200327_20-04028_20-00328_S25_L000_R1_001       GC Content  Count
# 0             0    0.0
# ...
# 180727-18-5425-18-01680_S8_L001_R2_001         GC Content  Count
# 0             0    0.0
# ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
# 191113_19-10150_20474_S132_L000_R2_001         GC Content      Count
# 0             0   3...
# 191113_19-10153_20477_S135_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
# 191113_19-10151_20475_S133_L000_R2_001         GC Content      Count
# 0             0   0...
# 191113_19-10151_20475_S133_L000_R1_001         GC Content  Count
# 0             0    0.0
# ...
#
#                                                                          Per base N content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001         Base   N-Count
# 0         1  0.479607
# 1 ...
# 200204_20-00746_19-03927_S9_L000_R1_001          Base   N-Count
# 0         1  0.009071
# 1 ...
# 181002-18-6991-775-18_S1_L001_R1_001             Base   N-Count
# 0         1  0.029292
# 1 ...
# 200327_20-04028_20-00328_S25_L000_R1_001         Base  N-Count
# 0         1      0.0
# 1   ...
# 180727-18-5425-18-01680_S8_L001_R2_001           Base  N-Count
# 0         1      0.0
# 1   ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001           Base   N-Count
# 0         1  0.080016
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001           Base   N-Count
# 0         1  0.000708
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001           Base   N-Count
# 0         1  0.080888
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001           Base   N-Count
# 0         1  0.000365
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001           Base   N-Count
# 0         1  0.083286
# 1 ...
#
#                                                                Sequence Length Distribution  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001       Length    Count
# 0     30-39   4192.0
# 1   ...
# 200204_20-00746_19-03927_S9_L000_R1_001        Length    Count
# 0     30-39    189.0
# 1   ...
# 181002-18-6991-775-18_S1_L001_R1_001           Length      Count
# 0     30-39     4566.0
# ...
# 200327_20-04028_20-00328_S25_L000_R1_001       Length     Count
# 0     30-39    8954.0
# 1 ...
# 180727-18-5425-18-01680_S8_L001_R2_001         Length  Count
# 0     65-69    1.0
# 1     70...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001         Length     Count
# 0     35-39    4455.0
# 1 ...
# 191113_19-10150_20474_S132_L000_R2_001         Length     Count
# 0     35-39    5799.0
# 1 ...
# 191113_19-10153_20477_S135_L000_R1_001         Length     Count
# 0     35-39    1949.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R2_001         Length     Count
# 0     35-39    4278.0
# 1 ...
# 191113_19-10151_20475_S133_L000_R1_001         Length     Count
# 0     35-39    4284.0
# 1 ...
#
#                                                                 Sequence Duplication Levels  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001     Duplication Level  Percentage of deduplicat...
# 200204_20-00746_19-03927_S9_L000_R1_001      Duplication Level  Percentage of deduplicat...
# 181002-18-6991-775-18_S1_L001_R1_001         Duplication Level  Percentage of deduplicat...
# 200327_20-04028_20-00328_S25_L000_R1_001     Duplication Level  Percentage of deduplicat...
# 180727-18-5425-18-01680_S8_L001_R2_001       Duplication Level  Percentage of deduplicat...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10150_20474_S132_L000_R2_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10153_20477_S135_L000_R1_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10151_20475_S133_L000_R2_001       Duplication Level  Percentage of deduplicat...
# 191113_19-10151_20475_S133_L000_R1_001       Duplication Level  Percentage of deduplicat...
#
#                                                                   Overrepresented sequences  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001              Empty DataFrame
# Columns: []
# Index: []
# 200204_20-00746_19-03927_S9_L000_R1_001               Empty DataFrame
# Columns: []
# Index: []
# 181002-18-6991-775-18_S1_L001_R1_001                  Empty DataFrame
# Columns: []
# Index: []
# 200327_20-04028_20-00328_S25_L000_R1_001              Empty DataFrame
# Columns: []
# Index: []
# 180727-18-5425-18-01680_S8_L001_R2_001                                                  ...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001                                                Se...
# 191113_19-10150_20474_S132_L000_R2_001                Empty DataFrame
# Columns: []
# Index: []
# 191113_19-10153_20477_S135_L000_R1_001                                                Se...
# 191113_19-10151_20475_S133_L000_R2_001                Empty DataFrame
# Columns: []
# Index: []
# 191113_19-10151_20475_S133_L000_R1_001                Empty DataFrame
# Columns: []
# Index: []
#
#                                                                             Adapter Content  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001     Position  Illumina Universal Adapter  Illum...
# 200204_20-00746_19-03927_S9_L000_R1_001      Position  Illumina Universal Adapter  Illum...
# 181002-18-6991-775-18_S1_L001_R1_001         Position  Illumina Universal Adapter  Illum...
# 200327_20-04028_20-00328_S25_L000_R1_001     Position  Illumina Universal Adapter  Illum...
# 180727-18-5425-18-01680_S8_L001_R2_001       Position  Illumina Universal Adapter  Illum...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10150_20474_S132_L000_R2_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10153_20477_S135_L000_R1_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10151_20475_S133_L000_R2_001       Position  Illumina Universal Adapter  Illum...
# 191113_19-10151_20475_S133_L000_R1_001       Position  Illumina Universal Adapter  Illum...
#
#                                                                             Module Statuses  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001  [pass, fail, pass, pass, fail, pass, pass, war...
# 200204_20-00746_19-03927_S9_L000_R1_001   [pass, pass, warn, pass, fail, pass, pass, war...
# 181002-18-6991-775-18_S1_L001_R1_001      [pass, fail, warn, pass, fail, warn, pass, war...
# 200327_20-04028_20-00328_S25_L000_R1_001  [pass, pass, pass, pass, fail, pass, pass, war...
# 180727-18-5425-18-01680_S8_L001_R2_001    [pass, fail, fail, pass, fail, fail, pass, war...
# ...                                                                                     ...
# 191113_19-10152_20476_S134_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10150_20474_S132_L000_R2_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10153_20477_S135_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10151_20475_S133_L000_R2_001    [pass, pass, pass, pass, fail, pass, pass, war...
# 191113_19-10151_20475_S133_L000_R1_001    [pass, pass, pass, pass, fail, pass, pass, war...
#
#                                          organism technology  read_number  \
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001      Sau         MS            2
# 200204_20-00746_19-03927_S9_L000_R1_001       Sau         MS            1
# 181002-18-6991-775-18_S1_L001_R1_001          Sau         MS            1
# 200327_20-04028_20-00328_S25_L000_R1_001      Sau         MS            1
# 180727-18-5425-18-01680_S8_L001_R2_001        Sau         MS            2
# ...                                           ...        ...          ...
# 191113_19-10152_20476_S134_L000_R1_001       Efcm         HS            1
# 191113_19-10150_20474_S132_L000_R2_001       Efcm         HS            2
# 191113_19-10153_20477_S135_L000_R1_001       Efcm         HS            1
# 191113_19-10151_20475_S133_L000_R2_001       Efcm         HS            2
# 191113_19-10151_20475_S133_L000_R1_001       Efcm         HS            1
#
#                                           evaluation
# filename
# 200709_20-07968_20-00891_S21_L000_R2_001           0
# 200204_20-00746_19-03927_S9_L000_R1_001            0
# 181002-18-6991-775-18_S1_L001_R1_001               0
# 200327_20-04028_20-00328_S25_L000_R1_001           0
# 180727-18-5425-18-01680_S8_L001_R2_001             0
# ...                                              ...
# 191113_19-10152_20476_S134_L000_R1_001             1
# 191113_19-10150_20474_S132_L000_R2_001             1
# 191113_19-10153_20477_S135_L000_R1_001             1
# 191113_19-10151_20475_S133_L000_R2_001             1
# 191113_19-10151_20475_S133_L000_R1_001             1
#
# [184 rows x 16 columns]

# %%
grouped = complete_reads.groupby(complete_reads.organism)
efcm = grouped.get_group('Efcm')
sau = grouped.get_group('Sau')
ecoli = grouped.get_group('Ecoli')

# %%
print('exported datasets')
print('efcm -', efcm.shape)
efcm.to_json('exported_datasets/efcm.json')
print('sau -', sau.shape)
sau.to_json('exported_datasets/sau.json')
print('ecoli -', ecoli.shape)
ecoli.to_json('exported_datasets/ecoli.json')
# Out:
# exported datasets
# efcm - (88, 16)
# sau - (78, 16)
# ecoli - (18, 16)
